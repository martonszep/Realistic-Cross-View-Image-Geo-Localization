# %% [markdown]
# # Git Handler for Colab

# %% [markdown]
# ### Setup

# %%
from google.colab import drive
import os

ROOT = '/content/gdrive'
drive.mount(ROOT) # mount drive

# %cd "/content/gdrive/MyDrive/adl4cv/Realistic-Cross-View-Image-Geo-Localization/"

# %%
# Edit the following variables:

GIT_USERNAME = "Notram1" 
GIT_TOKEN = ""  # GitHub / Settings / Developer settings / Personal access tokens / repo
GIT_REPOSITORY = "Realistic-Cross-View-Image-Geo-Localization"

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"

# %% [markdown]
# Clone repo to Google Drive or pull latest changes.

# %%
# !git clone "{GIT_PATH}" # clone the github repository
# !git pull origin main # pull latest changes
# !git checkout <your_branch>

# Change your identity
# !git config --local user.email "marton.szep@tum.de"
# !git config --local user.name "Marton Szep"

# print out branches
# !git log --graph --decorate --pretty=oneline --abbrev-commit --all

# show origin
# !git config --list --show-origin

# !git status

# %% [markdown]
# ### Save changes to GitHub

# %%
# !git status

# %%
# Add / track changed files
# !git add colab # beware of "git add .", usually you don't want to add EVERYTHING

# %%
# Commit changes (don't forget to change the message!)
# !git commit -m ""

# %%
# Push changes to GitHub repo
# !git push origin main
